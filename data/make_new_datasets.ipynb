# %%
import pandas as pd

# %%
full_data = pd.read_csv("additional_data/44k_parse_Labse_data.csv")
old_train = pd.read_csv("cleared_v2/cleared_v2_train_09.csv").rename(columns={'ru': 'rus'}).drop(columns=['ind'])
old_val = pd.read_csv('cleared_v2/cleared_v2_val_005.csv').rename(columns={'ru': 'rus'}).drop(columns=['ind'])
old_test = pd.read_csv('cleared_v2/cleared_v2_test_005.csv').rename(columns={'ru': 'rus'}).drop(columns=['ind'])

# %%
full_data
# Out:
#                                                                                                                             rus  \
# 0                                                                 – Я приехал из Новосибирска, живу там и учусь в 5-й гимназии.
# 1                                                  В Ханты-Мансийске часто бываю, город очень красивый, много деревьев, зелени.
# 2                                                                                                       Аня Прохоренко, 12 лет:
# 3                                                                                                            – Учусь в 7 школе.
# 4      На занятиях нас учили навыкам выживания в лесу, например, ориентироваться на местности, разводить костёр, дёготь делать.
# ...                                                                                                                         ...
# 44074                  В горы съездил, оленей пригнал, в лесу капканы, петли разыскал, подготовил, установил, в порядок привел.
# 44075                                             Смотрит, собак отцовских в лес берет, они не боятся его, словно он их хозяин.
# 44076                                     Наблюдая за ним, сердце ее наполнялось нежностью, все лучше и красивее он казался ей.
# 44077                                                        Над домом их всегда светит солнце, ненастья там никогда не бывает.
# 44078                                                                                И сейчас живут под солнечным чистым небом.
#
#                                                                                                                                                   mansi  \
# 0                                                                              – Ты ма̄н ам Новосибирск ӯсныл ёхтысум, тот 5 гимназият ханищтахтэ̄гум.
# 1                                      о̄пам Ханты-Мансийск ӯст са̄в тэ̄лат о̄ньщи, тыг ва̄тихал ёхталы, ам о̄с тав ётэ ӯнтылматсум, тыт ты минэ̄гум.
# 2                                                                                                                               Аня Прохоренко, 12 та̄л
# 3                                                                                                                         – Ам 7 школат ханищтахтэ̄гум.
# 4      о̄выл хо̄тал ма̄н хӯнтхӯрыг во̄рн миннэ ма̄гыс атсӯв, ханищтавесӯв, маныр ёт пинуӈкве э̄ри – ще̄ранка, касай, курска ос мо̄т э̄рнэ пормасыт.
# ...                                                                                                                                                 ...
# 44074                         Нё̄рн ялыс, са̄лыт по̄сыс, во̄рт ке̄рнялит, лэ̄сыт пуссын но̄х-хо̄нтсанэ, ёмщакв хот-щё̄питасанэ, ёмщакв но̄х-ӯнттысанэ.
# 44075                                                 Тувыл сунсы, а̄ще кӯтювыт акваг во̄рн тотыг-ла̄лыянэ, щар ат пилэ̄гыт, сома щар тав та о̄траныл.
# 44076                                                                   Сунсыме̄т сыме хотум та ка̄мнямас, акваг ёмас, нё̄тнэ хурипаг хотум та хартаве.
# 44077                                                                                 Колэ̄н нумпа̄лт акваг хо̄тал посты, турапыг нэ̄мхуньт ат е̄мталы.
# 44078                                                                                                           Хо̄талыӈ То̄рум ёлыпалыт ань та о̄лэ̄г.
#
#            score
# 0      86.012177
# 1      63.727867
# 2      87.849266
# 3      81.786835
# 4      67.694000
# ...          ...
# 44074  76.501633
# 44075  60.674404
# 44076  47.991787
# 44077  66.386452
# 44078  44.042419
#
# [44079 rows x 3 columns]

# %%
old_train
# Out:
#                                                                                               mansi  \
# 0                                         Та пыгрисит маим вармаль э̄рнэ поратэт ат вермгыг варункв
# 1                                                                          Вит са̄мыл сунсым о̄нтыс
# 2                                                       Атаявев, акваг лылынг тагл ворн та тотавев.
# 3                                              Ман ты пӣлтал, веськат хумиюв нэтхуньт ат ёрувлвылув
# 4                                                                       То̄лыг я̄ ко̄тильт та̄гапас
# ...                                                                                             ...
# 72081  А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄хматын ма̄гыс лю̄льсаӈыг сусхатуӈкве вēрмēгыт.
# 72082                                                             А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 72083                                                   Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 72084                    Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэнк Заппа ёт гастролин минас.
# 72085                                                    Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                                                          rus  \
# 0                                        Те мальчики не выполнят задание в назначенный срок.
# 1                                                                   Вода прибывала на глазах
# 2                                                 Обнюхивает нас, живыми на кладбище уносит.
# 3                                             Мы никогда не забудем этого честного человека.
# 4                                                              Невод зацепился по среди реки
# ...                                                                                      ...
# 72081                            Мне кажется, что подобные случаи могут вызывать подозрение.
# 72082                                                        Волосы аккуратно собраны сзади.
# 72083                                   В общем, культуры интенсивного потребления меда нет.
# 72084  Затем Уэйтс отправился на гастроли с такими музыкантами, как Чарли Рич и Фрэнк Заппа.
# 72085                                   Но разве можно вот так просто покинуть своих друзей?
#
#        split
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 72081  train
# 72082  train
# 72083  train
# 72084  train
# 72085  train
#
# [72086 rows x 3 columns]

# %%
replace_table_default = {
    '\uf519': 'о̄',
    '\uf523': 'э̄',
    '\uf50f': 'а̄',
    '\uf511': 'ē',
    '\uf529': 'а̄',
    '\uf518': 'о̄',
    '\uf528': 'Я̄',
    '\uf513': 'ё̄',
    '\uf522': 'Э̄',
    '\uf512': 'Ё̄',
    '\uf50e': 'А̄',
    '\uf521': 'ы̄',
    '\uf52d': 'ю̄',
    '\uf52c': 'Ю̄',
    '\uf510': 'Ē',
    'ū': 'ӣ',
    '\t': ' ',
    '\r': ' ',
    '\xa0': ' ',
    '\xad': '',
    '\\': ''
}

replace_table_macrons = {
    'ā': 'а̄',
    'Ā': 'А̄',
    'ӯ': 'ӯ',
    'Ӯ': 'Ӯ',
    'ȳ': 'ӯ',
    'Ȳ': 'Ӯ',
    'ō': 'о̄',
    'Ō': 'О̄',
    'ē': 'е̄',
    'Ē': 'Е̄',
    'ӣ': 'ӣ',
    'Ӣ': 'Ӣ',
    'ă': 'а̄',
    'á': 'а̄'
}

# %%
def full_data_preproc(df_orig: pd.DataFrame, change_macrons=False, cols2change=['rus', 'mansi']) -> pd.DataFrame:
    df = df_orig.copy()
    for col in cols2change:
        # замена символов, как при формировании трейна (еще давно)
        for old, new in replace_table_default.items():
            df[col] = df[col].apply(lambda x: x.replace(old, new))
            
        # замена символов на кириллицу + макрон
        if change_macrons:
            for old, new in replace_table_macrons.items():
                df[col] = df[col].apply(lambda x: x.replace(old, new))
                
        # удаление лишних пробелов
        df[col] = df[col].apply(lambda x: " ".join(x.split()))
    return df

# %%
pd.set_option('display.max_colwidth', None)

# %%
small_data = full_data[full_data.score > 60].copy().reset_index(drop=True)

# %% [markdown]
# # 1. Все новые данные, без изменения макронов

# %%
full_train_wout_macrons = pd.concat([
    full_data[['rus', 'mansi']],
    old_train[['rus', 'mansi']]
], axis=0, ignore_index=True).copy()

full_train_wout_macrons = full_data_preproc(
    full_train_wout_macrons,
    change_macrons=False,
    cols2change=['rus', 'mansi']
)

full_train_wout_macrons['split'] = 'train'
full_train_wout_macrons = full_train_wout_macrons[old_val.columns]
full_train_wout_macrons
# Out:
#                                                                                                                                                    mansi  \
# 0                                                                               – Ты ма̄н ам Новосибирск ӯсныл ёхтысум, тот 5 гимназият ханищтахтэ̄гум.
# 1                                       о̄пам Ханты-Мансийск ӯст са̄в тэ̄лат о̄ньщи, тыг ва̄тихал ёхталы, ам о̄с тав ётэ ӯнтылматсум, тыт ты минэ̄гум.
# 2                                                                                                                                Аня Прохоренко, 12 та̄л
# 3                                                                                                                          – Ам 7 школат ханищтахтэ̄гум.
# 4       о̄выл хо̄тал ма̄н хӯнтхӯрыг во̄рн миннэ ма̄гыс атсӯв, ханищтавесӯв, маныр ёт пинуӈкве э̄ри – ще̄ранка, касай, курска ос мо̄т э̄рнэ пормасыт.
# ...                                                                                                                                                  ...
# 116160                                                      А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄хматын ма̄гыс лю̄льсаӈыг сусхатуӈкве вēрмēгыт.
# 116161                                                                                                                 А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 116162                                                                                                       Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 116163                                                                        Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэнк Заппа ёт гастролин минас.
# 116164                                                                                                        Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                                                                                              rus  \
# 0                                                                  – Я приехал из Новосибирска, живу там и учусь в 5-й гимназии.
# 1                                                   В Ханты-Мансийске часто бываю, город очень красивый, много деревьев, зелени.
# 2                                                                                                        Аня Прохоренко, 12 лет:
# 3                                                                                                             – Учусь в 7 школе.
# 4       На занятиях нас учили навыкам выживания в лесу, например, ориентироваться на местности, разводить костёр, дёготь делать.
# ...                                                                                                                          ...
# 116160                                                               Мне кажется, что подобные случаи могут вызывать подозрение.
# 116161                                                                                           Волосы аккуратно собраны сзади.
# 116162                                                                      В общем, культуры интенсивного потребления меда нет.
# 116163                                     Затем Уэйтс отправился на гастроли с такими музыкантами, как Чарли Рич и Фрэнк Заппа.
# 116164                                                                      Но разве можно вот так просто покинуть своих друзей?
#
#         split
# 0       train
# 1       train
# 2       train
# 3       train
# 4       train
# ...       ...
# 116160  train
# 116161  train
# 116162  train
# 116163  train
# 116164  train
#
# [116165 rows x 3 columns]

# %%
full_train_wout_macrons.to_csv('cleared_v3/big_orig_preproc/cleared_v3_train_09.csv', index=False)
old_val.to_csv('cleared_v3/big_orig_preproc/cleared_v3_val_005.csv', index=False)
old_test.to_csv('cleared_v3/big_orig_preproc/cleared_v3_test_005.csv', index=False)

# %% [markdown]
# # 2. Все новые данные с замененными макронами (вал тест тоже)

# %%
val_with_macrons = full_data_preproc(
    old_val,
    change_macrons=True,
    cols2change=['rus', 'mansi']
)

test_with_macrons = full_data_preproc(
    old_test,
    change_macrons=True,
    cols2change=['rus', 'mansi']
)

# %%
full_train_with_macrons = pd.concat([
    full_data[['rus', 'mansi']],
    old_train[['rus', 'mansi']]
], axis=0, ignore_index=True).copy()

full_train_with_macrons = full_data_preproc(
    full_train_with_macrons,
    change_macrons=True,
    cols2change=['rus', 'mansi']
)

full_train_with_macrons['split'] = 'train'
full_train_with_macrons = full_train_with_macrons[old_val.columns]
full_train_with_macrons
# Out:
#                                                                                                                                                    mansi  \
# 0                                                                               – Ты ма̄н ам Новосибирск ӯсныл ёхтысум, тот 5 гимназият ханищтахтэ̄гум.
# 1                                       о̄пам Ханты-Мансийск ӯст са̄в тэ̄лат о̄ньщи, тыг ва̄тихал ёхталы, ам о̄с тав ётэ ӯнтылматсум, тыт ты минэ̄гум.
# 2                                                                                                                                Аня Прохоренко, 12 та̄л
# 3                                                                                                                          – Ам 7 школат ханищтахтэ̄гум.
# 4       о̄выл хо̄тал ма̄н хӯнтхӯрыг во̄рн миннэ ма̄гыс атсӯв, ханищтавесӯв, маныр ёт пинуӈкве э̄ри – ще̄ранка, касай, курска ос мо̄т э̄рнэ пормасыт.
# ...                                                                                                                                                  ...
# 116160                                                    А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄хматын ма̄гыс лю̄льсаӈыг сусхатуӈкве ве̄рме̄гыт.
# 116161                                                                                                                 А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 116162                                                                                                       Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 116163                                                                        Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэнк Заппа ёт гастролин минас.
# 116164                                                                                                        Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                                                                                              rus  \
# 0                                                                  – Я приехал из Новосибирска, живу там и учусь в 5-й гимназии.
# 1                                                   В Ханты-Мансийске часто бываю, город очень красивый, много деревьев, зелени.
# 2                                                                                                        Аня Прохоренко, 12 лет:
# 3                                                                                                             – Учусь в 7 школе.
# 4       На занятиях нас учили навыкам выживания в лесу, например, ориентироваться на местности, разводить костёр, дёготь делать.
# ...                                                                                                                          ...
# 116160                                                               Мне кажется, что подобные случаи могут вызывать подозрение.
# 116161                                                                                           Волосы аккуратно собраны сзади.
# 116162                                                                      В общем, культуры интенсивного потребления меда нет.
# 116163                                     Затем Уэйтс отправился на гастроли с такими музыкантами, как Чарли Рич и Фрэнк Заппа.
# 116164                                                                      Но разве можно вот так просто покинуть своих друзей?
#
#         split
# 0       train
# 1       train
# 2       train
# 3       train
# 4       train
# ...       ...
# 116160  train
# 116161  train
# 116162  train
# 116163  train
# 116164  train
#
# [116165 rows x 3 columns]

# %%
full_train_with_macrons.to_csv('cleared_v3/big_macrons_changed/cleared_v3_train_09.csv', index=False)
val_with_macrons.to_csv('cleared_v3/big_macrons_changed/cleared_v3_val_005.csv', index=False)
test_with_macrons.to_csv('cleared_v3/big_macrons_changed/cleared_v3_test_005.csv', index=False)

# %% [markdown]
# # 3. Данные после отсечки, без изменения макронов

# %%
small_train_wout_macrons = pd.concat([
    small_data[['rus', 'mansi']],
    old_train[['rus', 'mansi']]
], axis=0, ignore_index=True).copy()

small_train_wout_macrons = full_data_preproc(
    small_train_wout_macrons,
    change_macrons=False,
    cols2change=['rus', 'mansi']
)

small_train_wout_macrons['split'] = 'train'
small_train_wout_macrons = small_train_wout_macrons[old_val.columns]
small_train_wout_macrons
# Out:
#                                                                                                                                                   mansi  \
# 0                                                                              – Ты ма̄н ам Новосибирск ӯсныл ёхтысум, тот 5 гимназият ханищтахтэ̄гум.
# 1                                      о̄пам Ханты-Мансийск ӯст са̄в тэ̄лат о̄ньщи, тыг ва̄тихал ёхталы, ам о̄с тав ётэ ӯнтылматсум, тыт ты минэ̄гум.
# 2                                                                                                                               Аня Прохоренко, 12 та̄л
# 3                                                                                                                         – Ам 7 школат ханищтахтэ̄гум.
# 4      о̄выл хо̄тал ма̄н хӯнтхӯрыг во̄рн миннэ ма̄гыс атсӯв, ханищтавесӯв, маныр ёт пинуӈкве э̄ри – ще̄ранка, касай, курска ос мо̄т э̄рнэ пормасыт.
# ...                                                                                                                                                 ...
# 88961                                                      А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄хматын ма̄гыс лю̄льсаӈыг сусхатуӈкве вēрмēгыт.
# 88962                                                                                                                 А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 88963                                                                                                       Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 88964                                                                        Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэнк Заппа ёт гастролин минас.
# 88965                                                                                                        Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                                                                                             rus  \
# 0                                                                 – Я приехал из Новосибирска, живу там и учусь в 5-й гимназии.
# 1                                                  В Ханты-Мансийске часто бываю, город очень красивый, много деревьев, зелени.
# 2                                                                                                       Аня Прохоренко, 12 лет:
# 3                                                                                                            – Учусь в 7 школе.
# 4      На занятиях нас учили навыкам выживания в лесу, например, ориентироваться на местности, разводить костёр, дёготь делать.
# ...                                                                                                                         ...
# 88961                                                               Мне кажется, что подобные случаи могут вызывать подозрение.
# 88962                                                                                           Волосы аккуратно собраны сзади.
# 88963                                                                      В общем, культуры интенсивного потребления меда нет.
# 88964                                     Затем Уэйтс отправился на гастроли с такими музыкантами, как Чарли Рич и Фрэнк Заппа.
# 88965                                                                      Но разве можно вот так просто покинуть своих друзей?
#
#        split
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 88961  train
# 88962  train
# 88963  train
# 88964  train
# 88965  train
#
# [88966 rows x 3 columns]

# %%
small_train_wout_macrons.to_csv('cleared_v3/small_orig_preproc/cleared_v3_train_09.csv', index=False)
old_val.to_csv('cleared_v3/small_orig_preproc/cleared_v3_val_005.csv', index=False)
old_test.to_csv('cleared_v3/small_orig_preproc/cleared_v3_test_005.csv', index=False)

# %% [markdown]
# # 4. Данные после отсечки с замененными макронами (вал тест тоже)

# %%
small_train_with_macrons = pd.concat([
    small_data[['rus', 'mansi']],
    old_train[['rus', 'mansi']]
], axis=0, ignore_index=True).copy()

small_train_with_macrons = full_data_preproc(
    small_train_with_macrons,
    change_macrons=True,
    cols2change=['rus', 'mansi']
)

small_train_with_macrons['split'] = 'train'
small_train_with_macrons = small_train_with_macrons[old_val.columns]
small_train_with_macrons
# Out:
#                                                                                                                                                   mansi  \
# 0                                                                              – Ты ма̄н ам Новосибирск ӯсныл ёхтысум, тот 5 гимназият ханищтахтэ̄гум.
# 1                                      о̄пам Ханты-Мансийск ӯст са̄в тэ̄лат о̄ньщи, тыг ва̄тихал ёхталы, ам о̄с тав ётэ ӯнтылматсум, тыт ты минэ̄гум.
# 2                                                                                                                               Аня Прохоренко, 12 та̄л
# 3                                                                                                                         – Ам 7 школат ханищтахтэ̄гум.
# 4      о̄выл хо̄тал ма̄н хӯнтхӯрыг во̄рн миннэ ма̄гыс атсӯв, ханищтавесӯв, маныр ёт пинуӈкве э̄ри – ще̄ранка, касай, курска ос мо̄т э̄рнэ пормасыт.
# ...                                                                                                                                                 ...
# 88961                                                    А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄хматын ма̄гыс лю̄льсаӈыг сусхатуӈкве ве̄рме̄гыт.
# 88962                                                                                                                 А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 88963                                                                                                       Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 88964                                                                        Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэнк Заппа ёт гастролин минас.
# 88965                                                                                                        Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                                                                                             rus  \
# 0                                                                 – Я приехал из Новосибирска, живу там и учусь в 5-й гимназии.
# 1                                                  В Ханты-Мансийске часто бываю, город очень красивый, много деревьев, зелени.
# 2                                                                                                       Аня Прохоренко, 12 лет:
# 3                                                                                                            – Учусь в 7 школе.
# 4      На занятиях нас учили навыкам выживания в лесу, например, ориентироваться на местности, разводить костёр, дёготь делать.
# ...                                                                                                                         ...
# 88961                                                               Мне кажется, что подобные случаи могут вызывать подозрение.
# 88962                                                                                           Волосы аккуратно собраны сзади.
# 88963                                                                      В общем, культуры интенсивного потребления меда нет.
# 88964                                     Затем Уэйтс отправился на гастроли с такими музыкантами, как Чарли Рич и Фрэнк Заппа.
# 88965                                                                      Но разве можно вот так просто покинуть своих друзей?
#
#        split
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 88961  train
# 88962  train
# 88963  train
# 88964  train
# 88965  train
#
# [88966 rows x 3 columns]

# %%
small_train_with_macrons.to_csv('cleared_v3/small_macrons_changed/cleared_v3_train_09.csv', index=False)
val_with_macrons.to_csv('cleared_v3/small_macrons_changed/cleared_v3_val_005.csv', index=False)
test_with_macrons.to_csv('cleared_v3/small_macrons_changed/cleared_v3_test_005.csv', index=False)
